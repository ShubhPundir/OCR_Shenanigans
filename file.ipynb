# %%
import matplotlib.pyplot as plt
import cv2

# %%
import easyocr

# %%
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
Image("image.png")

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
output = reader.readtext('image.png')

# %%
output
# Out:
# [([[253, 70], [747, 70], [747, 106], [253, 106]],
#   'NUTRITIONAL INFORMATION (Approx: values)',
#   0.7103345626067369),
#  ([[238, 101], [760, 101], [760, 128], [238, 128]],
#   'No: of Servings per pack: 25 (Approx) Serving Size: 4Og (1 scoop)',
#   0.6518280457467556),
#  ([[532, 146], [574, 146], [574, 172], [532, 172]], 'Per', 0.9999843077989814),
#  ([[642, 150], [756, 150], [756, 176], [642, 176]],
#   'Per Serve',
#   0.9998777810540523),
#  ([[246, 158], [356, 158], [356, 188], [246, 188]],
#   'Nutrients',
#   0.9999945163651631),
#  ([[524, 172], [584, 172], [584, 204], [524, 204]],
#   '100g',
#   0.8348967432975769),
#  ([[667, 175], [721, 175], [721, 195], [667, 195]],
#   '%RDA-',
#   0.8688196573208455),
#  ([[512, 220], [598, 220], [598, 246], [512, 246]],
#   '445 Kcal',
#   0.9904029211204353),
#  ([[672, 220], [730, 220], [730, 246], [672, 246]],
#   '8.9 %',
#   0.6194882739569125),
#  ([[244, 244], [332, 244], [332, 268], [244, 268]],
#   'Total Fat',
#   0.9712172707818716),
#  ([[512, 244], [572, 244], [572, 272], [512, 272]],
#   '16.4 g',
#   0.8959713930878044),
#  ([[672, 244], [730, 244], [730, 268], [672, 268]],
#   '9.8 %',
#   0.7817638741152174),
#  ([[260, 266], [396, 266], [396, 292], [260, 292]],
#   'Saturated Fat',
#   0.6654536093758212),
#  ([[510, 266], [562, 266], [562, 294], [510, 294]],
#   '2.8 g',
#   0.9805932362994486),
#  ([[674, 266], [730, 266], [730, 290], [674, 290]],
#   '5.1 %',
#   0.9740209796134476),
#  ([[320, 288], [356, 288], [356, 314], [320, 314]], 'Fat', 0.9999991740938607),
#  ([[512, 288], [562, 288], [562, 316], [512, 316]],
#   '0.0 g',
#   0.9946192128896126),
#  ([[674, 288], [730, 288], [730, 314], [674, 314]],
#   '0.0 %',
#   0.6074608289371775),
#  ([[260, 310], [458, 310], [458, 338], [260, 338]],
#   'Polyunsaturated Fat',
#   0.999802947926594),
#  ([[512, 314], [544, 314], [544, 340], [512, 340]], '8 g', 0.9943647026903168),
#  ([[260, 334], [468, 334], [468, 358], [260, 358]],
#   'Monounsaturated Fat',
#   0.9994767599663968),
#  ([[512, 334], [546, 334], [546, 362], [512, 362]], '5 g', 0.9402468006235426),
#  ([[244, 356], [360, 356], [360, 382], [244, 382]],
#   'Cholesterol',
#   0.6202846783700247),
#  ([[512, 358], [580, 358], [580, 384], [512, 384]],
#   '0.0 mg',
#   0.9708418458331081),
#  ([[244, 378], [440, 378], [440, 406], [244, 406]],
#   'Total Carbohydrates',
#   0.6813080378662872),
#  ([[512, 378], [574, 378], [574, 406], [512, 406]],
#   '52.2 g',
#   0.8595011276251522),
#  ([[674, 380], [718, 380], [718, 404], [674, 404]], '16%', 0.9919732861006941),
#  ([[260, 401], [374, 401], [374, 431], [260, 431]],
#   'Total Sugar',
#   0.7207141870492796),
#  ([[512, 402], [562, 402], [562, 430], [512, 430]],
#   '6.0 g',
#   0.9593320784261917),
#  ([[294, 423], [423, 423], [423, 454], [294, 454]],
#   'Added Sugar',
#   0.742992129546134),
#  ([[510, 424], [562, 424], [562, 452], [510, 452]],
#   '0.0 g',
#   0.9896895074436322),
#  ([[674, 424], [714, 424], [714, 450], [674, 450]], '0 %', 0.9833257794380188),
#  ([[259, 444], [388, 444], [388, 474], [259, 474]],
#   'Dietary Fibre',
#   0.9985412224440929),
#  ([[512, 446], [574, 446], [574, 474], [512, 474]],
#   '11.3g',
#   0.894381376450311),
#  ([[684, 446], [740, 446], [740, 472], [684, 472]],
#   '1.3 %',
#   0.6121205043981433),
#  ([[244, 470], [320, 470], [320, 494], [244, 494]],
#   'Protein',
#   0.9999646301501377),
#  ([[512, 470], [558, 470], [558, 496], [512, 496]],
#   '22 g',
#   0.9971028566360474),
#  ([[674, 470], [740, 470], [740, 494], [674, 494]],
#   '16.4 %',
#   0.997921053515566),
#  ([[244, 492], [326, 492], [326, 516], [244, 516]],
#   'Calcuim',
#   0.9149794461374458),
#  ([[512, 492], [590, 492], [590, 520], [512, 520]],
#   '61.4 mg',
#   0.9751917720947368),
#  ([[674, 492], [730, 492], [730, 516], [674, 516]],
#   '2.5 %',
#   0.5806202730434646),
#  ([[244, 514], [288, 514], [288, 538], [244, 538]], 'Iron', 0.998436689376831),
#  ([[510, 514], [580, 514], [580, 542], [510, 542]],
#   '6.5 mg',
#   0.9983174099256762),
#  ([[674, 514], [726, 514], [726, 540], [674, 540]],
#   '10 %',
#   0.9880316589138562),
#  ([[244, 537], [348, 537], [348, 561], [244, 561]],
#   'Potassium',
#   0.9999451232375052),
#  ([[512, 536], [590, 536], [590, 562], [512, 562]],
#   '559.2 m',
#   0.7903777981021693),
#  ([[676, 536], [730, 536], [730, 562], [676, 562]],
#   '6.6 %',
#   0.9921974233215756),
#  ([[244, 560], [320, 560], [320, 584], [244, 584]],
#   'Sodium',
#   0.9999518680878745),
#  ([[512, 560], [590, 560], [590, 588], [512, 588]],
#   '10.5 mg',
#   0.9890950676087065),
#  ([[674, 560], [730, 560], [730, 584], [674, 584]],
#   '0.2 %',
#   0.7629124412339843),
#  ([[237, 613], [533, 613], [533, 633], [237, 633]],
#   '*as per RDA for Indians, ICMR-NIN, 2020',
#   0.739439837700854),
#  ([[559, 613], [763, 613], [763, 633], [559, 633]],
#   '%RDA values not estimated',
#   0.9576696755500722),
#  ([[272, 632], [728, 632], [728, 656], [272, 656]],
#   '~%RDA values per serving calculated on the basis of 200OKcal',
#   0.6994031025650892),
#  ([[232, 726], [350, 726], [350, 754], [232, 754]],
#   'Ingredients',
#   0.9993614941112287),
#  ([[360, 724], [748, 724], [748, 754], [360, 754]],
#   'Rolled Oats (61%), Unsweetened Peanut',
#   0.8393021857047828),
#  ([[233, 746], [746, 746], [746, 775], [233, 775]],
#   'Butter (26%), Alpino Supernatural (TM) Peanut Protein,',
#   0.7453815089537817),
#  ([[234, 769], [760, 769], [760, 798], [234, 798]],
#   'Cocoa Powder; Nuts & Seed Mix (Chia Seeds; Almonds;',
#   0.765957680471297),
#  ([[234, 791], [674, 791], [674, 820], [234, 820]],
#   'Raisins, Sunflower Seeds); Monk Fruit Extract',
#   0.7362369300195952),
#  ([[234, 834], [402, 834], [402, 862], [234, 862]],
#   'Proprietary Food',
#   0.9181164146211206),
#  ([[412, 834], [744, 834], [744, 864], [412, 864]],
#   'Breakfast Cereals including Rolled',
#   0.9636160568794426),
#  ([[234, 858], [282, 858], [282, 882], [234, 882]],
#   'Oats',
#   0.9997445344924927),
#  ([[233, 900], [432, 900], [432, 931], [233, 931]],
#   'Allergen Information',
#   0.8162295811949903),
#  ([[440, 899], [762, 899], [762, 928], [440, 928]],
#   'Contains Oats, Peanuts & Almonds',
#   0.8375828182438446),
#  ([[245.02202795004177, 217.16388105512118],
#    [317.9266084147509, 226.34048261076038],
#    [313.9779720499582, 251.83611894487882],
#    [241.07339158524914, 243.65951738923962]],
#   'Energy',
#   0.999243991426142),
#  ([[260.95805693252925, 285.1867537178289],
#    [321.90750559328086, 293.2608036627252],
#    [318.04194306747075, 317.8132462821711],
#    [257.09249440671914, 309.7391963372748]],
#   'Trans',
#   0.9999761161836157)]

# %%
for i in output:
    print(i[1])
# Out:
# NUTRITIONAL INFORMATION (Approx: values)
# No: of Servings per pack: 25 (Approx) Serving Size: 4Og (1 scoop)
# Per
# Per Serve
# Nutrients
# 100g
# %RDA-
# 445 Kcal
# 8.9 %
# Total Fat
# 16.4 g
# 9.8 %
# Saturated Fat
# 2.8 g
# 5.1 %
# Fat
# 0.0 g
# 0.0 %
# Polyunsaturated Fat
# 8 g
# Monounsaturated Fat
# 5 g
# Cholesterol
# 0.0 mg
# Total Carbohydrates
# 52.2 g
# 16%
# Total Sugar
# 6.0 g
# Added Sugar
# 0.0 g
# 0 %
# Dietary Fibre
# 11.3g
# 1.3 %
# Protein
# 22 g
# 16.4 %
# Calcuim
# 61.4 mg
# 2.5 %
# Iron
# 6.5 mg
# 10 %
# Potassium
# 559.2 m
# 6.6 %
# Sodium
# 10.5 mg
# 0.2 %
# *as per RDA for Indians, ICMR-NIN, 2020
# %RDA values not estimated
# ~%RDA values per serving calculated on the basis of 200OKcal
# Ingredients
# Rolled Oats (61%), Unsweetened Peanut
# Butter (26%), Alpino Supernatural (TM) Peanut Protein,
# Cocoa Powder; Nuts & Seed Mix (Chia Seeds; Almonds;
# Raisins, Sunflower Seeds); Monk Fruit Extract
# Proprietary Food
# Breakfast Cereals including Rolled
# Oats
# Allergen Information
# Contains Oats, Peanuts & Almonds
# Energy
# Trans
